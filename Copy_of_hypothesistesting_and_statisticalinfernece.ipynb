# %% [markdown]
# <a href="https://colab.research.google.com/github/SriSharanya-617/Hypotheisi_testing_statistical_inference/blob/main/Copy_of_hypothesistesting_and_statisticalinfernece.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import pandas as ps
import seaborn as sns
df=sns.load_dataset("taxis")
print(df.head())
print(df.size)
print(df.shape)
print(df.info())
print(df.describe())
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan
# 90062
# (6433, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB
# None
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
# std       1.203768     3.827867    11.551804     2.44856     1.415267
#
#              total
# count  6433.000000
# mean     18.517794
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000
# std      13.815570

# %%
print(df.describe(include=object))
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6433         6389            6407                   6388
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5451         4577             230                    245
#
#        pickup_borough dropoff_borough
# count            6407            6388
# unique              4               5
# top         Manhattan       Manhattan
# freq             5268            5206

# %%
df.isna().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
(df.shape[0]-df.dropna().shape[0])/df.shape[0]*100
# Out:
# 1.4301259132597544

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (6341, 14)

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6341                           6341
# mean   2019-03-16 08:30:26.574830080  2019-03-16 08:44:47.525784832
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:28:20            2019-03-08 15:54:00
# 50%              2019-03-15 21:57:47            2019-03-15 22:07:48
# 75%              2019-03-23 17:45:29            2019-03-23 17:57:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare          tip        tolls  \
# count  6341.000000  6341.000000  6341.000000  6341.000000  6341.000000
# mean      1.544078     2.997707    12.887931     1.972703     0.314793
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# 25%       1.000000     0.990000     6.500000     0.000000     0.000000
# 50%       1.000000     1.650000     9.500000     1.750000     0.000000
# 75%       2.000000     3.200000    15.000000     2.820000     0.000000
# max       6.000000    36.700000   150.000000    23.190000    24.020000
# std       1.207948     3.719775    10.722249     2.361897     1.369174
#
#              total
# count  6341.000000
# mean     18.310263
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000
# std      12.950365

# %%
df.reset_index(drop=True)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6336 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6337 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6338 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6339 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6340 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6336  1.06    0.0   6.36   green  credit card      East Harlem North
# 6337  0.00    0.0  58.80   green  credit card                Jamaica
# 6338  0.00    0.0  17.30   green         cash    Crown Heights North
# 6339  0.00    0.0   6.80   green  credit card          East New York
# 6340  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6336              Central Harlem North      Manhattan       Manhattan
# 6337  East Concourse/Concourse Village         Queens           Bronx
# 6338                    Bushwick North       Brooklyn        Brooklyn
# 6339      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6340                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6341 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
df.describe(include='object')
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6341         6341            6341                   6341
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5373         4546             227                    244
#
#        pickup_borough dropoff_borough
# count            6341            6341
# unique              4               5
# top         Manhattan       Manhattan
# freq             5226            5172

# %% [markdown]
# *EDA*
# tip is targe column
#
#
# tip is a numerical feature .you have to analyze categrical data

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
#graphical analysis of categorical data
#for bar plot estimator is mean

# %%
sns.barplot(x=df.color,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
sns.barplot(x=df.color,y=df.tip,estimator='std')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
sns.histplot(x=df.tip,hue=df.color,kde=True)
plt.show()

# %% [markdown]
# Bar plot: Shows clear class imbalance; Yellow has much higher count than Green.
#
# Histogram: Confirms skewed distribution with most values concentrated in Yellow.
#
# 📊 Bar Plot – Insights
#
# The bar plot shows a strong class imbalance.
#
# Yellow dominates the dataset with ~85% of the total data.
#
# Green represents only ~15%, making it a minority class.
#
# This imbalance can bias machine learning models toward predicting Yellow more often.
#
# For classification tasks, techniques like:
#
# Resampling
#
# SMOTE
#
# Class weighting
# may be required.
#
# 👉 Conclusion: The dataset is not evenly distributed across colors.
#
# 📈 Histogram – Insights
#
# Since the feature is categorical (color), the histogram appears as two spikes.
#
# The spike for Yellow is significantly taller than Green.
#
# This indicates:
#
# High frequency of Yellow values
#
# Low variation in categories
#
# Histogram confirms the skewed distribution seen in the bar plot.
#
# 👉 Conclusion: Data distribution is heavily skewed toward Yellow.

# %%
# Independent T-Test
yellow_tip = df['tip'][df['color']=='yellow']
green_tip = df['tip'][df['color']=='green']

# %% [markdown]
# h0:distribution of tip for yellow=distribution of green
# h1:distribution of tip for yellow not equal distribution of green

# %%
green_tip.shape
# Out:
# (968,)

# %%
yellow_tip.shape
# Out:
# (5373,)

# %%
from scipy import stats
t_stat,p_val=stats.ttest_ind(yellow_tip,green_tip)
print("P-value:", p_val)
# Out:
# P-value: 7.791088119489451e-64

# %%
if p_val < 0.05:
  print("Reject null hypothesis the tip for yellow category is different that of green ")
else:
  print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis the tip for yellow category is different that of green

# %%
df.payment.value_counts()
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %%
sns.barplot(x=df.payment,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
sns.barplot(x=df.payment,y=df.tip,estimator='std')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
df.payment.value_counts()
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
sns.histplot(x=df.tip,hue=df.payment,kde=True)
plt.show()

# %%
# Independent T-Test
yellow_tip = df['tip'][df['payment']=='yellow']
green_tip = df['tip'][df['payment']=='green']

# %%
green_tip.shape
# Out:
# (0,)

# %%
yellow_tip.shape
# Out:
# (0,)

# %%
from scipy import stats
t_stat,p_val=stats.ttest_ind(yellow_tip,green_tip)
print("P-value:", p_val)
# Out:
# P-value: nan
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/deprecation.py:234: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return f(*args, **kwargs)

# %%
if p_val < 0.05:
  print("Reject null hypothesis the tip for yellow category is different that of green ")
else:
  print("Fail to reject null hypothesis")
# Out:
# Fail to reject null hypothesis

# %%
df['pickup_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Bronx', 'Brooklyn'], dtype=object)

# %%
sns.countplot(df['pickup_borough'],palette={'Manhattan':'red','Queens':'blue','Bronx':'green','Brooklyn':'purple'})
# Out:
# /tmp/ipython-input-1237546309.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df['pickup_borough'],palette={'Manhattan':'red','Queens':'blue','Bronx':'green','Brooklyn':'purple'})
# <Axes: xlabel='count', ylabel='pickup_borough'>

# %%
sns.barplot(x=df['pickup_borough'],y=df['tip'],palette='Set2')
# Out:
# /tmp/ipython-input-2462997792.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'],y=df['tip'],palette='Set2')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['pickup_borough']).mean()
# Out:
# pickup_borough
# Bronx        0.148586
# Brooklyn     0.979127
# Manhattan    1.945597
# Queens       3.066458
# Name: tip, dtype: float64

# %%
df['tip'].groupby(df['pickup_borough']).std()
# Out:
# pickup_borough
# Bronx        0.897261
# Brooklyn     1.674487
# Manhattan    1.997736
# Queens       4.323951
# Name: tip, dtype: float64

# %%
sns.histplot(x=df['tip'],hue=df['pickup_borough'],kde=True,bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# H0:distribution of tip is the same across all pickup_borough categories
#
# H1:At least one category has a different distribution of tipANOVA Test
# Definition: ANOVA (Analysis of Variance) compares means of three or more groups.
#
# Hypotheses:
#
# H0: Mean is the same across all the pickup_borough categories
# H1: At least one category has a different distribution of tip

# %%
manhattan_tip = df['tip'][df['pickup_borough'] == 'Manhattan']
queens_tip = df['tip'][df['pickup_borough'] == 'Queens']
bronx_tip = df['tip'][df['pickup_borough'] == 'Bronx']
brooklyn_tip = df['tip'][df['pickup_borough'] == 'Brooklyn']

print(manhattan_tip)
print(queens_tip)
print(bronx_tip)
print(brooklyn_tip)
# Out:
# 0       2.15
# 1       0.00
# 2       2.36
# 3       6.15
# 4       1.10
#         ...
# 6420    0.00
# 6422    0.00
# 6424    0.00
# 6426    0.50
# 6428    1.06
# Name: tip, Length: 5226, dtype: float64
# 10      0.00
# 22      8.31
# 43      0.00
# 53      0.00
# 56      0.00
#         ...
# 6403    0.00
# 6417    0.00
# 6418    1.76
# 6423    0.00
# 6429    0.00
# Name: tip, Length: 638, dtype: float64
# 92      0.0
# 174     0.0
# 612     0.0
# 1214    0.0
# 1848    0.0
#        ...
# 6387    0.0
# 6393    0.0
# 6410    0.0
# 6413    0.0
# 6427    0.0
# Name: tip, Length: 99, dtype: float64
# 114     5.58
# 155     1.46
# 214     0.00
# 266     3.76
# 332     0.00
#         ...
# 6421    0.00
# 6425    0.00
# 6430    0.00
# 6431    0.00
# 6432    3.36
# Name: tip, Length: 378, dtype: float64

# %%
# ANOVA Test
from scipy import stats
f_stat, p_val = stats.f_oneway(manhattan_tip,queens_tip,bronx_tip,brooklyn_tip)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)
if p_val < 0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# ANOVA F-statistic: 91.5793383185057
# P-value: 5.155109332422435e-58
# Reject null hypothesis

# %% [markdown]
# Reject null hypothesis
# but anova test doesn't tell which grp is different so we go for post-hoc test
#
# Post-hoc Test: Tukey HSD
# Definition: After ANOVA indicates a significant difference, Tukey HSD helps identify which pairs of groups differ significantly.
#
# Hypotheses for Tukey test (for each pair of groups):

# %%
# Tukey HSD Test
from statsmodels.stats.multicomp import pairwise_tukeyhsd
# Perform Tukey HSD
tukey_result = pairwise_tukeyhsd(endog=df.tip, groups=df.pickup_borough, alpha=0.05)
print(tukey_result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#   group1    group2  meandiff p-adj lower  upper  reject
# -------------------------------------------------------
#     Bronx  Brooklyn   0.8305 0.008 0.1595 1.5015   True
#     Bronx Manhattan    1.797   0.0  1.194    2.4   True
#     Bronx    Queens   2.9179   0.0 2.2759 3.5599   True
#  Brooklyn Manhattan   0.9665   0.0 0.6499  1.283   True
#  Brooklyn    Queens   2.0873   0.0 1.7016 2.4731   True
# Manhattan    Queens   1.1209   0.0 0.8716 1.3701   True
# -------------------------------------------------------

# %%
sns.countplot(x=df['dropoff_borough'],palette='Set2')
# Out:
# /tmp/ipython-input-3711686064.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['dropoff_borough'],palette='Set2')
# <Axes: xlabel='dropoff_borough', ylabel='count'>

# %%
sns.histplot(hue=df['dropoff_borough'],x=df['tip'],bins=30,kde=True)
plt.show()

# %%
df['tip'].groupby(df['dropoff_borough']).std()
# Out:
# dropoff_borough
# Bronx            1.788795
# Brooklyn         2.896229
# Manhattan        2.052074
# Queens           3.947016
# Staten Island    2.976920
# Name: tip, dtype: float64

# %%
manhattan_tip1=df['tip'][df['dropoff_borough']=='Manhattan']
queens_tip1=df['tip'][df['dropoff_borough']=='Queens']
bronx_tip1=df['tip'][df['dropoff_borough']=='Bronx']
brooklyn_tip1=df['tip'][df['dropoff_borough']=='Brooklyn']
staten_island_tip1=df['tip'][df['dropoff_borough']=='Staten Island']

# %%
# ANOVA Test
from scipy import stats
f_stat, p_val = stats.f_oneway(manhattan_tip1,queens_tip1,bronx_tip1,brooklyn_tip1,staten_island_tip1)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)
if p_val < 0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# ANOVA F-statistic: 31.42417796696829
# P-value: 5.87859571331583e-26
# Reject null hypothesis

# %%
# Tukey HSD Test
from statsmodels.stats.multicomp import pairwise_tukeyhsd
# Perform Tukey HSD
tukey_result = pairwise_tukeyhsd(endog=df.tip, groups=df.dropoff_borough, alpha=0.05)
print(tukey_result)
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==============================================================
#   group1      group2    meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#     Bronx      Brooklyn   1.3869    0.0  0.7691  2.0046   True
#     Bronx     Manhattan   1.4296    0.0  0.8751  1.9842   True
#     Bronx        Queens   1.8873    0.0  1.2742  2.5005   True
#     Bronx Staten Island  13.6303    0.0  9.0833 18.1773   True
#  Brooklyn     Manhattan   0.0427 0.9952 -0.2571  0.3425  False
#  Brooklyn        Queens   0.5004 0.0055  0.1026  0.8983   True
#  Brooklyn Staten Island  12.2434    0.0  7.7204 16.7664   True
# Manhattan        Queens   0.4577 0.0002  0.1675  0.7479   True
# Manhattan Staten Island  12.2007    0.0  7.6859 16.7154   True
#    Queens Staten Island   11.743    0.0  7.2206 16.2653   True
# --------------------------------------------------------------

# %%
sns.countplot(x=df['pickup_zone'])
# Out:
# <Axes: xlabel='pickup_zone', ylabel='count'>

# %%
sns.countplot(x=df['dropoff_zone'])
# Out:
# <Axes: xlabel='dropoff_zone', ylabel='count'>

# %%
categories=[group['tip'].values for name,group in df.groupby('pickup_zone')]
f_stat,p_val=stats.f_oneway(manhattan_tip,queens_tip,bronx_tip,brooklyn_tip)
print("p-value:",p_val)
alpha=0.05
if p_val <alpha:
  print("reject null hypothesis")
else:
  print("fail to reject null hypothesis")
# Out:
# p-value: 5.155109332422435e-58
# reject null hypothesis

# %%
categories=[group['tip'].values for name,group in df.groupby('dropoff_zone')]
f_stat,p_val=stats.f_oneway(manhattan_tip,queens_tip,bronx_tip,brooklyn_tip,staten_island_tip1)
print("p-value:",p_val)
alpha=0.05
if p_val <alpha:
  print("reject null hypothesis")
else:
  print("fail to reject null hypothesis")
# Out:
# p-value: 1.9431901719787484e-68
# reject null hypothesis

# %%
sns.histplot(df['tip'],kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(df['passengers'],kde=True)
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %%
sns.scatterplot(x=df['tip'],y=df['passengers'])
# Out:
# <Axes: xlabel='tip', ylabel='passengers'>

# %%
r,p_val=stats.pearsonr(df['tip'],df['distance'])
print("correlation ",r)
print("p_value:",p_val)
alpha=0.05
if p_val <alpha:
  print("reject null hypothesis")
else:
  print("fail to reject null hypothesis")
# Out:
# correlation  0.4769796821455606
# p_value: 0.0
# reject null hypothesis

# %%
r,p_val=stats.spearmanr(df['tip'],df['distance'])
print("correlation ",r)
print("p_value:",p_val)
alpha=0.05
if p_val <alpha:
  print("reject null hypothesis")
else:
  print("fail to reject null hypothesis")
# Out:
# correlation  0.29265085410043695
# p_value: 1.9411181331374707e-125
# reject null hypothesis

# %%
sns.scatterplot(x=df['tip'],y=df['fare'])
# Out:
# <Axes: xlabel='tip', ylabel='fare'>

# %%
sns.scatterplot(x=df['tip'],y=df['tolls'])
# Out:
# <Axes: xlabel='tip', ylabel='tolls'>
